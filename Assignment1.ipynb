# %%
#Question 1 C3

5: Datatype  int
5.0 : Datatype decimal
5 > 1:Datatype Boolean
'5': Datatype char
5 * 2: Datatype  int
'5' * 2: Datatype int
'5' + '2': Datatype char
5 / 2: Datatype Decimal
5 % 2: Datatype int 
{5, 2, 1}:Datatype List
5 == 3: Datatype Boolean
Pi (the number) :Datatype Decimal

# %%
#Question 2 C#
#a)

using System;
					
public class Program
{
	public static void Main()
	{
		
		string str = "Supercalifragilisticexpialidocious";
		int result = str.Length;
		Console.WriteLine("There are {0} letters ",result);
	}
}

# b) Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

using System;
					
public class Program
{
	public static void Main()
	{
		
		string str = "Supercalifragilisticexpialidocious";
		bool result = str.Contains("ice");
		Console.WriteLine("Does 'Supercalifragilisticexpialidocious' contain 'ice'? :  {0} ",result);
	}
}
#c. Which of the following words is the longest:
#Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?

using System;
					
public class Program
{
	public static void Main()
	{
		
		string str1 = "Supercalifragilisticexpialidocious";
		string str3= "Honorificabilitudinitatibus";
		string str2= "Bababadalgharaghtakamminarronnkonn";
		
		string[] list = {str1,str2,str3};
		
		int max = list[0].Length;	
		for(int j = 1; j < list.Length; j++) {		
			for(int i = 1; i < list.Length; i++) {
			max = Math.Max(max, list[i].Length);

			}
		}
		for(int k= 0; k< list.Length; k++) {
		 if(list[k].Length==34)
			 {
			  Console.WriteLine("The longest word  is {0}",list[k]);
			 
			 }
		}

		 
}
}

#d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
#'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

using System;
using System.Collections.Generic;					
public class Program
{
	public static void Main()
	{
		
		var name = new List<string>();
				
		name.Add("Berlioz");
		 name.Add("Borodin");
		 name.Add("Brian");
		 name.Add("Bartok");
		 name.Add("Bellini");
		 name.Add("Buxtehude");
		 name.Add("Bernstein");
		
		 name.Sort();
    for (int i = 0; i < name.Count; i++)
    {
        Console.WriteLine(name[i]);
    }
		Console.WriteLine("The first composer is {0}",name[0]);
		 
}
}

# %%
#Question 3 C#
#Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
#sides of a triangle and returns the area of the triangle. By Heron's formula, the area
#of a triangle with side lengths a, b, and c is s(s − a)(s −b)(s −c), where
#s = (a + b + c)/2.

using System;
namespace AreaTriangulo
{
public class Triangulo
{
	public double a;
	public double b;
	public double c;
	public double r2;
	public double s;
	public double r1;
	
	public double getArea()
	{
		
		s = (a + b + c)/2;
		r1= s*(s-a)*(s-b)*(s-c);
		r2=Math.Sqrt(r1);
		return r2;
		

	}
	public void display()
	{
	 Console.WriteLine("Area: {0}",getArea());
	}
		 
}
public class ExecuteTriangulo
{
	
	public static void Main(string[] args)
	{
		Triangulo r=new Triangulo();
		r.a=2;
		r.b=2;
		r.c=2;
		r.display();
		Console.WriteLine();
	}
	
}
		
}

# %%
#Question 4 C#
#Write a program in C# Sharp to separate odd and even integers in separate arrays.
#Go to the editor
#Test Data :
#Input the number of elements to be stored in the array :5
#Input 5 elements in the array :
#element - 0 : 25
#element - 1 : 47
#element - 2 : 42
#element - 3 : 56
#element - 4 : 32
#Expected Output:
#The Even elements are:
#42 56 32
#The Odd elements are :
#B
#25 47

using System;
					
public class Program
{
	public static void Main(string[] args)
	{
		int[] arr=new int[5];
		arr[0]=25;
		arr[1]=47;
		arr[2]=42;
		arr[3]=56;
		arr[4]=32;
		int j=0;
		int k=0;
		 for (int i = 0; i < arr.Length; i++)
    	{
			 if(arr[i]%2==0)
			 {
			 
				 j=j+1;
			 }
			 else{k=k+1;}
		}
		int ac1=0;
		int ac2=0;
		int[] arr_even=new int[j];
		int[] arr_odd=new int[k];
		 for (int i = 0; i < arr.Length; i++)
    	{
			 if(arr[i]%2==0)
			 {
				 
			  	 arr_even[ac1]=arr[i];
				 ac1+=1;
			 }
			 else{
				 
			 	 arr_odd[ac2]=arr[i];
				 ac2+=1;
			 }
		}	
	Console.WriteLine("The Odd elements are: ");	
		
	for (int r= 0; r<arr_odd.Length; r++)
   {	
	Console.WriteLine(arr_odd[r]);
	}
	Console.WriteLine("The Even elements are: ");		
	for (int r= 0; r<arr_even.Length; r++)
   {	
		
	Console.WriteLine(arr_even[r]);
	}
		
	}		
		
}

# %%
#Question 5 C#
#a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
#dependingonwhetherthepoint(x,y)liesintherectanglewithlowerleft
#corner (x1,y1) and upper right corner (x2,y2).
#>>> inside(1,1,0,0,2,3)
#True
#>>> inside(-1,-1,0,0,2,3)
#False

#b. Use function inside()from part a. to write an expression that tests whether
#the point (1,1) lies in both of the following rectangles: one with lower left
#corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
#left corner (0.5, 0.2) and upper right corner (1.1, 2).

using System;
namespace Data
{

	public class inside1
	{
		public int x;
		public int y;
		public int x1;
		public int y1;
		public int x2;
		public int y2;
		
	public  bool  inside(int x,int y,int x1, int y1,int x2, int y2)
	{
		if (x > x1 && x < x2 && y > y1 && y < y2)
		{ return true;}
 		else{return false;}
		
	}
		
	}
	public class Executeinside
	{
		public static void Main(string[] args)
		{
			inside1 r=new inside1();
			bool t= r.inside(-1,-1,0,0,2,3);
			Console.WriteLine(t);
		}
	}

}

# %%
#Question 6 Python
#16. You can turn a word into pig-Latin using the following two rules(simplified):
#• If the word starts with a consonant, move that letter to the end and append
#'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
#• If the word starts with a vowel, simply append 'way' to the end of the word.
#For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway' . For
#our purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
#Write a function pig() that takes a word (i.e., a string) as input and returns its pigLatin form. Your function should still work if the input word contains upper case
#characters. Your output should always be lower case however.

def pig(letter):
    Worday = 'ay'
    wordway = 'way'
    consonant_word = ['B','C','D','F','G','H','J','K','L','M','N','P','Q','R','S','T','V','X','Z']
    vowel_word = ['A','E','I','O','U','Y']
    enterword = input('Please enter a word to turn into Pig Latin: ')
    fletter = enterword[0]
    fletter = str(fletter)
    fletter=fletter.upper()
    if fletter in consonant_word:   
        print('The word in Pig_Latin is:',enterword[1:]+fletter+Worday)
        return enterword[1:]+fletter+Worday
    elif fletter in vowel_word:   
        print('The word in Pig_Latin is:',enterword+wordway)
    return enterword+wordway

print(pig('Happy'))

# %%
#Question 7 Python
#File bloodtype1.txt records blood-types of patients (A, B, AB, O or OO) at a clinic.
#Write a function bldcount() that reads the file with name name and reports (i.e.,
#prints) how many patients there are in each bloodtype.
#>>> bldcount('bloodtype.txt')
#There are 10 patients of blood type A.
#There is one patient of blood type B.
#There are 10 patients of blood type AB.
#There are 12 patients of blood type O.
#There are no patients of blood type OO.


def bidcount(file):
    infile=open(file)
    content=infile.read()
    wordlist=content.split()
    i=0
    j=0
    k=0
    l=0
    n=0
    for word  in wordlist:
        if 'AB' in word:
            i=i+1
        if 'B' in word:
            j=j+1
        if 'O' in word:
            k=k+1
        if 'A' in word:
            l=l+1
        if 'OO' in word:
            n=n+1   
    print(f'There are {i} de tipo AB')
    print(f'There are {j} de tipo B')
    print(f'There are {k} de tipo O')
    print(f'There are {l} de tipo A')
    print(f'There are {n} de tipo OO')
    
bidcount('bloodtype1.txt')

# %%
#Question 8 Python
#Write a function curconv() that takes as input:
#1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or
#'EUR' for the Euro)
#2. an amount
#and then converts and returns the amount in US dollars.

def concorv(currency,amount):
    
    infile=open('currencies.txt')
    myline=infile.readlines()
    for m in myline:
        #print(m)
        a=m[:3].strip()
        b=m[4:14].strip()
        c=m[14:32].strip()
        
        if a==currency:
             return float(b)*amount
            
concorv('EUR',100)

# %%
#Question 9 Python
#Each of the following will cause an exception (an error). Identify what type of
#exception each will cause.

#Trying to add incompatible variables, as in
#adding 6 + ‘a’

try:
    b = 6+'a'
except Exception as error:
    print(error)

#Referring to the 12th item of a list that has only 10
#items

list = ['B','C','D','F','G','H','J','K','L','M']
   
try:
    a =list[12] +'y'
except Exception as error:
    print(error)
    
#Using a value that is out ofrange for a function’s
#input, such as calling math.sqrt(-1.0)

try:
    y =math.sqrt(-1.0)
except Exception as error:
    print(error)
    
#Using an undeclared variable, such as print(x)
#when x has not been defined

try:
    print(x)
except Exception as error:
    print(error)
#Trying to open a file that does not exist, such as
#mistyping the file name or looking in the wrong
#directory.

try:    
    infile=open('archivo.txt')
    content=infile.read()    
except Exception as error:
    print(error)

# %%
#Question 10 Python
#Encryption is the process of hiding the meaning of a text by substituting letters in the
#message with other letters, according to some system. If the process is successful, no
#one but the intended recipient can understand the encrypted message. Cryptanalysis
#refers to attempts to undo the encryption, even if some details of the encryption are
#unknown (for example, if an encrypted message has been intercepted). The first step
#of cryptanalysis is often to build up a table of letter frequencies in the encrypted text.
#Assume that the string letters is already defined as
#'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies()
#that takes a string as its only parameter, and returns a list of integers, showing the
#number of times each character appears in the text. Your function may ignore any
#characters that are not in letters.
def frequencies(letter):    
    x=letter
    i=0
    j=0  
    s=len(x)
    arr=[]
    #print(x[0:1])
    while i<len(x):    
        # return x[i:1]    
       # print(i)    
        j=0    
       # print(x[i:1])
        r=0
        while j<len(x):
            if x[i:i+1]==x[j:j+1]:
                r=r+1  
            j=j+1      
        i=i+1
        #
       # print(x[i:i+1])
        #print(x[j:j+1])
        #k=i-1
        #arr[k]=r
        arr.append(r)
    return arr
frequencies('abcdefghijklmnopqrstuvwxyz')
